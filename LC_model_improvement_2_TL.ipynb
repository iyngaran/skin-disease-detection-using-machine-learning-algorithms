# %%
import zipfile
import os

#os.system("rm -rf ipythonUtils")
#os.system("rm -rf lesion-diagnosis")
#os.system("rm -rf lesion-diagnosis-ver2.zip")
#os.system("rm -rf test")
#os.system("rm -rf train")

isExist = os.path.exists("ipython-utils")
if not os.path.exists("ipython-utils"):
    # !git clone https://github.com/iyngaran/ipythonUtils.git


if not os.path.exists("lesion-diagnosis-ver2.zip"):
    # !wget  https://testing.idev55.com/lesion-diagnosis-ver2.zip

if not os.path.exists("lesion-diagnosis"):
    # Unzip the downloaded file
    zip_file = zipfile.ZipFile("lesion-diagnosis-ver2.zip", "r")
    zip_file.extractall()
    zip_file.close()
# Out:
# Cloning into 'ipythonUtils'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 6), reused 20 (delta 5), pack-reused 0
# Unpacking objects: 100% (21/21), done.
# --2022-10-16 19:44:28--  https://testing.idev55.com/lesion-diagnosis-ver2.zip
# Resolving testing.idev55.com (testing.idev55.com)... 3.84.41.34
# Connecting to testing.idev55.com (testing.idev55.com)|3.84.41.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1501915604 (1.4G) [application/zip]
# Saving to: ‘lesion-diagnosis-ver2.zip’
#
# lesion-diagnosis-ve 100%[===================>]   1.40G  34.0MB/s    in 44s
#
# 2022-10-16 19:45:12 (32.9 MB/s) - ‘lesion-diagnosis-ver2.zip’ saved [1501915604/1501915604]

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("lesion-diagnosis"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 10 directories and 1 images in 'lesion-diagnosis'.
# There are 0 directories and 430 images in 'lesion-diagnosis/solar-lentigo'.
# There are 0 directories and 261 images in 'lesion-diagnosis/vascular-lesion'.
# There are 0 directories and 677 images in 'lesion-diagnosis/squamous-cell-carcinoma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/nevus'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/melanoma'.
# There are 0 directories and 912 images in 'lesion-diagnosis/actinic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/basal-cell-carcinoma'.
# There are 0 directories and 255 images in 'lesion-diagnosis/dermatofibroma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/seborrheic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/pigmented-benign-keratosis'.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
import Augmentor
p = Augmentor.Pipeline("lesion-diagnosis/solar-lentigo")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(570) ## We are adding 570 samples.

p = Augmentor.Pipeline("lesion-diagnosis/vascular-lesion")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(739) ## We are adding 739 samples.

p = Augmentor.Pipeline("lesion-diagnosis/dermatofibroma")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(745) ## We are adding 745 samples.


p = Augmentor.Pipeline("lesion-diagnosis/squamous-cell-carcinoma")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(323) ## We are adding 323 samples.

p = Augmentor.Pipeline("lesion-diagnosis/actinic-keratosis")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(88) ## We are adding 88 samples per class.
# Out:
# Initialised with 428 image(s) found.
# Output directory set to lesion-diagnosis/solar-lentigo/output.
# Processing <PIL.Image.Image image mode=RGB size=3264x2448 at 0x7FE3B3BF9CD0>: 100%|██████████| 570/570 [01:54<00:00,  5.00 Samples/s]
# Initialised with 259 image(s) found.
# Output directory set to lesion-diagnosis/vascular-lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FE3B3BB6C50>: 100%|██████████| 739/739 [00:24<00:00, 30.56 Samples/s]
# Initialised with 253 image(s) found.
# Output directory set to lesion-diagnosis/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE3AE7DC310>: 100%|██████████| 745/745 [00:46<00:00, 16.09 Samples/s]
# Initialised with 675 image(s) found.
# Output directory set to lesion-diagnosis/squamous-cell-carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE3AE9229D0>: 100%|██████████| 323/323 [00:19<00:00, 16.26 Samples/s]
# Initialised with 910 image(s) found.
# Output directory set to lesion-diagnosis/actinic-keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7FE3AE8BDA90>: 100%|██████████| 88/88 [00:05<00:00, 15.88 Samples/s]

# %%
# !mv lesion-diagnosis/solar-lentigo/output/* lesion-diagnosis/solar-lentigo/
# !mv lesion-diagnosis/vascular-lesion/output/* lesion-diagnosis/vascular-lesion/
# !mv lesion-diagnosis/dermatofibroma/output/* lesion-diagnosis/dermatofibroma/
# !mv lesion-diagnosis/squamous-cell-carcinoma/output/* lesion-diagnosis/squamous-cell-carcinoma/
# !mv lesion-diagnosis/actinic-keratosis/output/* lesion-diagnosis/actinic-keratosis/


# !rm -rf lesion-diagnosis/solar-lentigo/output
# !rm -rf lesion-diagnosis/vascular-lesion/output
# !rm -rf lesion-diagnosis/dermatofibroma/output
# !rm -rf lesion-diagnosis/squamous-cell-carcinoma/output
# !rm -rf lesion-diagnosis/actinic-keratosis/output

# %%
for dirpath, dirnames, filenames in os.walk("lesion-diagnosis"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 10 directories and 1 images in 'lesion-diagnosis'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/solar-lentigo'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/vascular-lesion'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/squamous-cell-carcinoma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/nevus'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/melanoma'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/actinic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/basal-cell-carcinoma'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/dermatofibroma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/seborrheic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/pigmented-benign-keratosis'.

# %%
from ipythonUtils.generateTestTrain import generate_test_and_train_datasets
if not os.path.exists("train/actinic-keratosis"):
   generate_test_and_train_datasets()

# %%
import pathlib
import numpy as np

data_dir = pathlib.Path("train") 
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['actinic-keratosis' 'basal-cell-carcinoma' 'dermatofibroma' 'melanoma'
#  'nevus' 'pigmented-benign-keratosis' 'seborrheic-keratosis'
#  'solar-lentigo' 'squamous-cell-carcinoma' 'vascular-lesion']

# %%
data_dir_train = pathlib.Path("train")
data_dir_test = pathlib.Path("test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.JPG')))
image_count_test = len(list(data_dir_test.glob('*/*.JPG')))
image_count_train, image_count_test
# Out:
# (7989, 2001)

# %%
from ipythonUtils.generateTestTrain import view_random_image
img = view_random_image(target_dir="train", target_class="melanoma")
# Out:
# Image shape: (2448, 3264, 3)

# %%
img2 = view_random_image(target_dir="test", target_class="nevus")
# Out:
# Image shape: (2448, 3264, 3)

# %%
img.shape, img2.shape
# Out:
# ((2448, 3264, 3), (2448, 3264, 3))

# %%
batch_size = 32
img_height = 180
img_width = 180
num_classes = len(class_names)
IMAGE_SHAPE = (img_width, img_height)
BATCH_SIZE = 32
epochs = 50

# %%
import tensorflow as tf

## create train dataset

## get all the train images and resizing them to the size of img_height*img_width and create batches
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 7989 files belonging to 10 classes.
# Using 6392 files for training.

# %%
## create validation dataset
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 7989 files belonging to 10 classes.
# Using 1597 files for validation.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(len(class_names)-1):
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.subplot(3, 3, i + 1)
    plt.imshow(img)
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %%
# Resnet 50 V2 feature vector
resnet_url = "https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4"

# # New: EfficientNetB0 feature vector (version 2)
efficientnet_url = "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b0/feature_vector/2"

# %%
# Create tensorboard callback (functionized because need to create a new one for each model)
import datetime
def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# %%
def create_model(model_url, num_classes=10):
  """Takes a TensorFlow Hub URL and creates a Keras Sequential model with it.
  
  Args:
    model_url (str): A TensorFlow Hub feature extraction URL.
    num_classes (int): Number of output neurons in output layer,
      should be equal to number of target classes, default 10.

  Returns:
    An uncompiled Keras Sequential model with model_url as feature
    extractor layer and Dense output layer with num_classes outputs.
  """
  # Download the pretrained model and save it as a Keras layer
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_SHAPE+(3,)) # define the input image shape
  
  # Create our own model
  model = tf.keras.Sequential([
    feature_extractor_layer, # use the feature extraction layer as the base
    layers.Dense(num_classes, activation='softmax', name='output_layer') # create our own output layer      
  ])

  return model

# %%
# Create model
resnet_model = create_model(resnet_url, num_classes=num_classes)

# Compile
resnet_model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

# %%
# Fit the model
resnet_history = resnet_model.fit(train_dataset,
                                  epochs=5,
                                  steps_per_epoch=len(train_dataset),
                                  validation_data=val_dataset,
                                  validation_steps=len(val_dataset),
                                  # Add TensorBoard callback to model (callbacks parameter takes a list)
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", # save experiment logs here
                                                                         experiment_name="resnet50V2")]) # name of log files
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet50V2/20221016-194938
# Epoch 1/5
# 200/200 [==============================] - 93s 144ms/step - loss: 41.8925 - accuracy: 0.1608 - val_loss: 32.1625 - val_accuracy: 0.1484
# Epoch 2/5
# 200/200 [==============================] - 16s 78ms/step - loss: 23.2852 - accuracy: 0.1988 - val_loss: 20.5552 - val_accuracy: 0.1866
# Epoch 3/5
# 200/200 [==============================] - 16s 79ms/step - loss: 24.7532 - accuracy: 0.2137 - val_loss: 22.7768 - val_accuracy: 0.1954
# Epoch 4/5
# 200/200 [==============================] - 16s 81ms/step - loss: 21.6562 - accuracy: 0.2337 - val_loss: 19.9409 - val_accuracy: 0.2411
# Epoch 5/5
# 200/200 [==============================] - 18s 92ms/step - loss: 20.6858 - accuracy: 0.2491 - val_loss: 26.8274 - val_accuracy: 0.2354

# %%
# If you wanted to, you could really turn this into a helper function to load in with a helper.py script...
import matplotlib.pyplot as plt

# Plot the validation and training data separately
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(resnet_history)

# %%
# Resnet summary 
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (K  (None, 2048)             23564800
#  erasLayer)
#
#  output_layer (Dense)        (None, 10)                20490
#
# =================================================================
# Total params: 23,585,290
# Trainable params: 20,490
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
from tensorflow import keras

data_augmentation = keras.Sequential([
      layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
from glob import glob
path_list = [ x for x in glob(os.path.join(data_dir_train, '*', '*.JPG')) ] 
lesion_list = [ os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.JPG')) ]
print(len(lesion_list))
# Out:
# 7989

# %%
df_dict_original = dict(zip(path_list, lesion_list))
list(df_dict_original.items())[:2]
# Out:
# [('train/solar-lentigo/solar-lentigo_original_ISIC_0058449.JPG_6719811d-a3a2-45e2-bd2d-2dedeb731ade.JPG',
#   'solar-lentigo'),
#  ('train/solar-lentigo/solar-lentigo_original_ISIC_0062421.JPG_d1b7422f-0f2b-49ec-b6a1-101fd2a4c55e.JPG',
#   'solar-lentigo')]

# %%
import pandas as pd
original_df = pd.DataFrame(list(df_dict_original.items()), columns=['Path','Label'])
original_df.head()
# Out:
#                                                 Path          Label
# 0  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 1  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 2  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 3  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 4  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# basal-cell-carcinoma          799
# dermatofibroma                799
# melanoma                      799
# nevus                         799
# pigmented-benign-keratosis    799
# seborrheic-keratosis          799
# solar-lentigo                 799
# squamous-cell-carcinoma       799
# vascular-lesion               799
# actinic-keratosis             798
# dtype: int64

# %%
original_df[['Label']].value_counts(normalize=True)
# Out:
# Label
# basal-cell-carcinoma          0.100013
# dermatofibroma                0.100013
# melanoma                      0.100013
# nevus                         0.100013
# pigmented-benign-keratosis    0.100013
# seborrheic-keratosis          0.100013
# solar-lentigo                 0.100013
# squamous-cell-carcinoma       0.100013
# vascular-lesion               0.100013
# actinic-keratosis             0.099887
# dtype: float64

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(1000) ## We are adding 1000 samples per class.
# Out:
# Initialised with 798 image(s) found.
# Output directory set to train/actinic-keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE2C8B2EC50>: 100%|██████████| 1000/1000 [01:55<00:00,  8.62 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/basal-cell-carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FE2C8F58910>: 100%|██████████| 1000/1000 [01:45<00:00,  9.49 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FE2C8BB6690>: 100%|██████████| 1000/1000 [02:47<00:00,  5.98 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FE2C652CD10>: 100%|██████████| 1000/1000 [08:46<00:00,  1.90 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3264x2448 at 0x7FE3AE86CFD0>: 100%|██████████| 1000/1000 [15:10<00:00,  1.10 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/pigmented-benign-keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE3B3C4CF50>: 100%|██████████| 1000/1000 [00:29<00:00, 34.23 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/seborrheic-keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2592x1936 at 0x7FE2C8F49A10>: 100%|██████████| 1000/1000 [03:47<00:00,  4.40 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/solar-lentigo/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FE3B3957750>: 100%|██████████| 1000/1000 [06:41<00:00,  2.49 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/squamous-cell-carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FE3B3C14090>: 100%|██████████| 1000/1000 [02:28<00:00,  6.72 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/vascular-lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE2C64F4FD0>: 100%|██████████| 1000/1000 [01:13<00:00, 13.56 Samples/s]

# %%
total_train_images = len(list(data_dir_train.glob('*/output/*.JPG')))
print(total_train_images)
# Out:
# 10000

# %%
from glob import glob
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.JPG'))]
path_list_new[:2]
# Out:
# ['train/solar-lentigo/output/solar-lentigo_original_ISIC_0011831.JPG_ff24e391-31b1-4562-bb12-ece666f2f9b8.JPG',
#  'train/solar-lentigo/output/solar-lentigo_original_ISIC_7264353.JPG_b21e68c7-9e79-40b3-a290-9ca6a277c603.JPG']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.JPG'))]
lesion_list_new[:2]
# Out:
# ['solar-lentigo', 'solar-lentigo']

# %%
import pandas as pd
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

df_2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df_2)
new_df.shape
# Out:
# (17989, 2)

# %%
new_df.head()
# Out:
#                                                 Path          Label
# 0  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 1  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 2  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 3  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 4  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo

# %%
# Checking the class distribution after adding the new images
new_df['Label'].value_counts(normalize=True)
# Out:
# solar-lentigo                 0.100006
# vascular-lesion               0.100006
# squamous-cell-carcinoma       0.100006
# nevus                         0.100006
# melanoma                      0.100006
# basal-cell-carcinoma          0.100006
# dermatofibroma                0.100006
# seborrheic-keratosis          0.100006
# pigmented-benign-keratosis    0.100006
# actinic-keratosis             0.099950
# Name: Label, dtype: float64

# %%
new_df['Label'].value_counts()
# Out:
# solar-lentigo                 1799
# vascular-lesion               1799
# squamous-cell-carcinoma       1799
# nevus                         1799
# melanoma                      1799
# basal-cell-carcinoma          1799
# dermatofibroma                1799
# seborrheic-keratosis          1799
# pigmented-benign-keratosis    1799
# actinic-keratosis             1798
# Name: Label, dtype: int64

# %%
# Create model
resnet_model = create_model(resnet_url, num_classes=num_classes)

# Compile
resnet_model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

# %%
# data_dir_train="path to directory with training data + data created using augmentor"
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 17989 files belonging to 10 classes.
# Using 14392 files for training.

# %%
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 17989 files belonging to 10 classes.
# Using 3597 files for validation.

# %%
# Fit the model
resnet_history = resnet_model.fit(train_dataset,
                                  epochs=epochs,
                                  steps_per_epoch=len(train_dataset),
                                  validation_data=val_dataset,
                                  validation_steps=len(val_dataset),
                                  # Add TensorBoard callback to model (callbacks parameter takes a list)
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", # save experiment logs here
                                                                         experiment_name="resnet50V2")]) # name of log files
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet50V2/20221016-203837
# Epoch 1/50
# 450/450 [==============================] - 170s 373ms/step - loss: 21.2458 - accuracy: 0.2494 - val_loss: 23.7738 - val_accuracy: 0.2747
# Epoch 2/50
# 450/450 [==============================] - 159s 348ms/step - loss: 21.8013 - accuracy: 0.2533 - val_loss: 19.1495 - val_accuracy: 0.2463
# Epoch 3/50
# 450/450 [==============================] - 156s 341ms/step - loss: 17.9326 - accuracy: 0.2769 - val_loss: 14.1859 - val_accuracy: 0.3130
# Epoch 4/50
# 450/450 [==============================] - 156s 342ms/step - loss: 18.2020 - accuracy: 0.2833 - val_loss: 30.3258 - val_accuracy: 0.1635
# Epoch 5/50
# 450/450 [==============================] - 156s 343ms/step - loss: 20.7620 - accuracy: 0.2843 - val_loss: 16.9424 - val_accuracy: 0.3208
# Epoch 6/50
# 450/450 [==============================] - 156s 343ms/step - loss: 18.6051 - accuracy: 0.3060 - val_loss: 25.9487 - val_accuracy: 0.2533
# Epoch 7/50
# 450/450 [==============================] - 156s 342ms/step - loss: 18.0981 - accuracy: 0.3069 - val_loss: 15.8226 - val_accuracy: 0.3053
# Epoch 8/50
# 450/450 [==============================] - 155s 341ms/step - loss: 18.1310 - accuracy: 0.3160 - val_loss: 21.9706 - val_accuracy: 0.3292
# Epoch 9/50
# 450/450 [==============================] - 156s 343ms/step - loss: 18.6251 - accuracy: 0.3150 - val_loss: 24.6163 - val_accuracy: 0.3481
# Epoch 10/50
# 450/450 [==============================] - 156s 342ms/step - loss: 19.5254 - accuracy: 0.3105 - val_loss: 21.3699 - val_accuracy: 0.3230
# Epoch 11/50
# 450/450 [==============================] - 156s 342ms/step - loss: 17.6498 - accuracy: 0.3256 - val_loss: 20.7565 - val_accuracy: 0.3150
# Epoch 12/50
# 450/450 [==============================] - 156s 343ms/step - loss: 19.0803 - accuracy: 0.3210 - val_loss: 21.9630 - val_accuracy: 0.3125
# Epoch 13/50
# 450/450 [==============================] - 162s 354ms/step - loss: 15.8976 - accuracy: 0.3446 - val_loss: 19.4601 - val_accuracy: 0.3155
# Epoch 14/50
# 450/450 [==============================] - 155s 341ms/step - loss: 17.6580 - accuracy: 0.3347 - val_loss: 16.0427 - val_accuracy: 0.3192
# Epoch 15/50
# 450/450 [==============================] - 157s 344ms/step - loss: 17.0487 - accuracy: 0.3360 - val_loss: 12.3307 - val_accuracy: 0.3567
# Epoch 16/50
# 450/450 [==============================] - 156s 342ms/step - loss: 17.1396 - accuracy: 0.3378 - val_loss: 14.9899 - val_accuracy: 0.3497
# Epoch 17/50
# 450/450 [==============================] - 156s 341ms/step - loss: 16.1891 - accuracy: 0.3456 - val_loss: 15.6304 - val_accuracy: 0.3233
# Epoch 18/50
# 450/450 [==============================] - 156s 342ms/step - loss: 16.4044 - accuracy: 0.3525 - val_loss: 19.2196 - val_accuracy: 0.2599
# Epoch 19/50
# 450/450 [==============================] - 155s 340ms/step - loss: 16.6968 - accuracy: 0.3537 - val_loss: 19.4861 - val_accuracy: 0.2755
# Epoch 20/50
# 450/450 [==============================] - 157s 345ms/step - loss: 17.7983 - accuracy: 0.3548 - val_loss: 15.8029 - val_accuracy: 0.3214
# Epoch 21/50
# 450/450 [==============================] - 156s 343ms/step - loss: 17.2217 - accuracy: 0.3565 - val_loss: 33.0773 - val_accuracy: 0.3158
# Epoch 22/50
# 450/450 [==============================] - 156s 343ms/step - loss: 17.4402 - accuracy: 0.3542 - val_loss: 11.1741 - val_accuracy: 0.3508
# Epoch 23/50
# 450/450 [==============================] - 158s 346ms/step - loss: 17.6077 - accuracy: 0.3514 - val_loss: 17.3468 - val_accuracy: 0.3122
# Epoch 24/50
# 450/450 [==============================] - 156s 342ms/step - loss: 15.7863 - accuracy: 0.3725 - val_loss: 27.9423 - val_accuracy: 0.3197
# Epoch 25/50
# 450/450 [==============================] - 156s 343ms/step - loss: 14.8540 - accuracy: 0.3718 - val_loss: 18.2011 - val_accuracy: 0.3464
# Epoch 26/50
# 450/450 [==============================] - 156s 342ms/step - loss: 15.0240 - accuracy: 0.3748 - val_loss: 19.7084 - val_accuracy: 0.2800
# Epoch 27/50
# 450/450 [==============================] - 156s 342ms/step - loss: 17.0808 - accuracy: 0.3607 - val_loss: 16.9823 - val_accuracy: 0.3225
# Epoch 28/50
# 450/450 [==============================] - 155s 341ms/step - loss: 16.4412 - accuracy: 0.3699 - val_loss: 24.6763 - val_accuracy: 0.3353
# Epoch 29/50
# 450/450 [==============================] - 156s 342ms/step - loss: 15.3032 - accuracy: 0.3752 - val_loss: 15.8106 - val_accuracy: 0.2627
# Epoch 30/50
# 450/450 [==============================] - 156s 341ms/step - loss: 15.8901 - accuracy: 0.3765 - val_loss: 18.0398 - val_accuracy: 0.3953
# Epoch 31/50
# 450/450 [==============================] - 155s 341ms/step - loss: 14.2577 - accuracy: 0.3890 - val_loss: 17.2982 - val_accuracy: 0.3656
# Epoch 32/50
# 450/450 [==============================] - 155s 341ms/step - loss: 15.1808 - accuracy: 0.3785 - val_loss: 22.8062 - val_accuracy: 0.3645
# Epoch 33/50
# 450/450 [==============================] - 155s 341ms/step - loss: 16.4727 - accuracy: 0.3778 - val_loss: 10.6229 - val_accuracy: 0.4112
# Epoch 34/50
# 450/450 [==============================] - 156s 342ms/step - loss: 14.2545 - accuracy: 0.3953 - val_loss: 14.1132 - val_accuracy: 0.3684
# Epoch 35/50
# 450/450 [==============================] - 156s 343ms/step - loss: 14.0196 - accuracy: 0.3981 - val_loss: 22.1546 - val_accuracy: 0.2975
# Epoch 36/50
# 450/450 [==============================] - 155s 340ms/step - loss: 16.3824 - accuracy: 0.3813 - val_loss: 12.7734 - val_accuracy: 0.3647
# Epoch 37/50
# 450/450 [==============================] - 155s 340ms/step - loss: 15.4133 - accuracy: 0.3858 - val_loss: 20.7564 - val_accuracy: 0.3859
# Epoch 38/50
# 450/450 [==============================] - 155s 340ms/step - loss: 14.9023 - accuracy: 0.3996 - val_loss: 15.5779 - val_accuracy: 0.3703
# Epoch 39/50
# 450/450 [==============================] - 156s 341ms/step - loss: 17.7996 - accuracy: 0.3784 - val_loss: 12.0337 - val_accuracy: 0.3756
# Epoch 40/50
# 450/450 [==============================] - 155s 341ms/step - loss: 14.4909 - accuracy: 0.3993 - val_loss: 26.9703 - val_accuracy: 0.3333
# Epoch 41/50
# 450/450 [==============================] - 156s 341ms/step - loss: 15.6442 - accuracy: 0.3923 - val_loss: 22.1097 - val_accuracy: 0.3297
# Epoch 42/50
# 450/450 [==============================] - 156s 341ms/step - loss: 15.7082 - accuracy: 0.3938 - val_loss: 16.0744 - val_accuracy: 0.3895
# Epoch 43/50
# 450/450 [==============================] - 156s 343ms/step - loss: 16.4976 - accuracy: 0.3917 - val_loss: 19.8573 - val_accuracy: 0.2914
# Epoch 44/50
# 450/450 [==============================] - 155s 341ms/step - loss: 13.2971 - accuracy: 0.4136 - val_loss: 15.9730 - val_accuracy: 0.3917
# Epoch 45/50
# 450/450 [==============================] - 157s 344ms/step - loss: 17.5812 - accuracy: 0.3840 - val_loss: 18.0551 - val_accuracy: 0.3378
# Epoch 46/50
# 450/450 [==============================] - 156s 343ms/step - loss: 15.0869 - accuracy: 0.3990 - val_loss: 16.6866 - val_accuracy: 0.3748
# Epoch 47/50
# 450/450 [==============================] - 155s 341ms/step - loss: 15.5818 - accuracy: 0.4039 - val_loss: 12.9716 - val_accuracy: 0.3825
# Epoch 48/50
# 450/450 [==============================] - 156s 343ms/step - loss: 15.2282 - accuracy: 0.4088 - val_loss: 21.5610 - val_accuracy: 0.3411
# Epoch 49/50
# 450/450 [==============================] - 155s 340ms/step - loss: 13.8059 - accuracy: 0.4136 - val_loss: 15.9239 - val_accuracy: 0.3742
# Epoch 50/50
# 450/450 [==============================] - 156s 341ms/step - loss: 15.8355 - accuracy: 0.4029 - val_loss: 30.4266 - val_accuracy: 0.2394

# %%
plot_loss_curves(resnet_history)

# %%
acc = resnet_history.history['accuracy']
val_accuracy = resnet_history.history['val_accuracy']

loss = resnet_history.history['loss']
val_loss = resnet_history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Resnet summary 
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (K  (None, 2048)             23564800
#  erasLayer)
#
#  output_layer (Dense)        (None, 10)                20490
#
# =================================================================
# Total params: 23,585,290
# Trainable params: 20,490
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

plot_model(resnet_model, show_shapes=True, show_layer_names=True)

# %%
def plot_history(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Train loss vs Validation loss')
  plt.ylabel('loss') 
  plt.xlabel('epoch') 
  plt.legend([ 'train' , 'validation' ], loc='upper right') 
  plt.show()


plot_history(resnet_history)

# %%
plt.plot(resnet_history.history['accuracy'])
plt.plot(resnet_history.history['val_accuracy'])
plt.title('Train accuracy vs Validation Accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch') 
plt.legend([ 'train' , 'validation' ], loc= 'upper right') 
plt.show()

# %%
# Create model
efficientnet_model = create_model(model_url=efficientnet_url, # use EfficientNetB0 TensorFlow Hub URL
                                  num_classes=num_classes)

# Compile EfficientNet model
efficientnet_model.compile(loss='sparse_categorical_crossentropy',
                           optimizer=tf.keras.optimizers.Adam(),
                           metrics=['accuracy'])

# Fit EfficientNet model 
efficientnet_history = efficientnet_model.fit(train_dataset, # only use 10% of training data
                                              epochs=epochs, # train for 5 epochs
                                              steps_per_epoch=len(train_dataset),
                                              validation_data=val_dataset,
                                              validation_steps=len(val_dataset),
                                              callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", 
                                                                                     # Track logs under different experiment name
                                                                                     experiment_name="efficientnetB0")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/efficientnetB0/20221016-231007
# Epoch 1/50
# 450/450 [==============================] - 170s 360ms/step - loss: 28.2200 - accuracy: 0.1289 - val_loss: 21.9396 - val_accuracy: 0.1357
# Epoch 2/50
# 450/450 [==============================] - 152s 334ms/step - loss: 16.8859 - accuracy: 0.1740 - val_loss: 17.1351 - val_accuracy: 0.1629
# Epoch 3/50
# 450/450 [==============================] - 152s 333ms/step - loss: 13.4907 - accuracy: 0.1984 - val_loss: 16.7099 - val_accuracy: 0.1576
# Epoch 4/50
# 450/450 [==============================] - 152s 333ms/step - loss: 11.8614 - accuracy: 0.2226 - val_loss: 15.1519 - val_accuracy: 0.1565
# Epoch 5/50
# 450/450 [==============================] - 152s 334ms/step - loss: 10.6650 - accuracy: 0.2351 - val_loss: 14.8478 - val_accuracy: 0.1732
# Epoch 6/50
# 450/450 [==============================] - 151s 332ms/step - loss: 10.1929 - accuracy: 0.2497 - val_loss: 15.4703 - val_accuracy: 0.1776
# Epoch 7/50
# 450/450 [==============================] - 152s 334ms/step - loss: 10.0073 - accuracy: 0.2526 - val_loss: 15.3007 - val_accuracy: 0.1824
# Epoch 8/50
# 450/450 [==============================] - 152s 333ms/step - loss: 9.8532 - accuracy: 0.2601 - val_loss: 15.4537 - val_accuracy: 0.1907
# Epoch 9/50
# 450/450 [==============================] - ETA: 0s - loss: 9.8109 - accuracy: 0.2629

# %%
plot_loss_curves(efficientnet_history)

# %%
acc = efficientnet_history.history['accuracy']
val_accuracy = efficientnet_history.history['val_accuracy']

loss = efficientnet_history.history['loss']
val_loss = efficientnet_history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
efficientnet_model.summary()

# %%
from keras.utils.vis_utils import plot_model

plot_model(efficientnet_model, show_shapes=True, show_layer_names=True)

# %%
def plot_history(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Train loss vs Validation loss')
  plt.ylabel('loss') 
  plt.xlabel('epoch') 
  plt.legend([ 'train' , 'validation' ], loc='upper right') 
  plt.show()


plot_history(efficientnet_history)

# %%
plt.plot(efficientnet_history.history['accuracy'])
plt.plot(efficientnet_history.history['val_accuracy'])
plt.title('Train accuracy vs Validation Accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch') 
plt.legend([ 'train' , 'validation' ], loc= 'upper right') 
plt.show()
