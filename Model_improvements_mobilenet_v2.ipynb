# %%
import zipfile
import os

#os.system("rm -rf ipythonUtils")
#os.system("rm -rf lesion-diagnosis")
#os.system("rm -rf lesion-diagnosis-ver2.zip")
#os.system("rm -rf test")
#os.system("rm -rf train")

isExist = os.path.exists("ipython-utils")
if not os.path.exists("ipython-utils"):
    # !git clone https://github.com/iyngaran/ipythonUtils.git


if not os.path.exists("lesion-diagnosis-ver2.zip"):
    # !wget  https://testing.idev55.com/lesion-diagnosis-ver2.zip

if not os.path.exists("lesion-diagnosis"):
    # Unzip the downloaded file
    zip_file = zipfile.ZipFile("lesion-diagnosis-ver2.zip", "r")
    zip_file.extractall()
    zip_file.close()
# Out:
# Cloning into 'ipythonUtils'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 6), reused 20 (delta 5), pack-reused 0
# Unpacking objects: 100% (21/21), done.
# --2022-10-16 19:50:25--  https://testing.idev55.com/lesion-diagnosis-ver2.zip
# Resolving testing.idev55.com (testing.idev55.com)... 3.84.41.34
# Connecting to testing.idev55.com (testing.idev55.com)|3.84.41.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1501915604 (1.4G) [application/zip]
# Saving to: ‘lesion-diagnosis-ver2.zip’
#
# lesion-diagnosis-ve 100%[===================>]   1.40G  12.7MB/s    in 1m 59s
#
# 2022-10-16 19:52:25 (12.0 MB/s) - ‘lesion-diagnosis-ver2.zip’ saved [1501915604/1501915604]

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("lesion-diagnosis"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 10 directories and 1 images in 'lesion-diagnosis'.
# There are 0 directories and 430 images in 'lesion-diagnosis/solar-lentigo'.
# There are 0 directories and 261 images in 'lesion-diagnosis/vascular-lesion'.
# There are 0 directories and 677 images in 'lesion-diagnosis/squamous-cell-carcinoma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/nevus'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/melanoma'.
# There are 0 directories and 912 images in 'lesion-diagnosis/actinic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/basal-cell-carcinoma'.
# There are 0 directories and 255 images in 'lesion-diagnosis/dermatofibroma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/seborrheic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/pigmented-benign-keratosis'.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
import Augmentor
p = Augmentor.Pipeline("lesion-diagnosis/solar-lentigo")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(570) ## We are adding 570 samples.

p = Augmentor.Pipeline("lesion-diagnosis/vascular-lesion")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(739) ## We are adding 739 samples.

p = Augmentor.Pipeline("lesion-diagnosis/dermatofibroma")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(745) ## We are adding 745 samples.


p = Augmentor.Pipeline("lesion-diagnosis/squamous-cell-carcinoma")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(323) ## We are adding 323 samples.

p = Augmentor.Pipeline("lesion-diagnosis/actinic-keratosis")
p.flip_top_bottom(probability=0.8)
p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
p.sample(88) ## We are adding 88 samples per class.
# Out:
# Initialised with 428 image(s) found.
# Output directory set to lesion-diagnosis/solar-lentigo/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F0FB8B57350>: 100%|██████████| 570/570 [01:52<00:00,  5.07 Samples/s]
# Initialised with 259 image(s) found.
# Output directory set to lesion-diagnosis/vascular-lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0FB8B19C10>: 100%|██████████| 739/739 [00:23<00:00, 31.98 Samples/s]
# Initialised with 253 image(s) found.
# Output directory set to lesion-diagnosis/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F0FB8BF1CD0>: 100%|██████████| 745/745 [00:39<00:00, 18.97 Samples/s]
# Initialised with 675 image(s) found.
# Output directory set to lesion-diagnosis/squamous-cell-carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F0FB8B81C90>: 100%|██████████| 323/323 [00:18<00:00, 17.36 Samples/s]
# Initialised with 910 image(s) found.
# Output directory set to lesion-diagnosis/actinic-keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0FBDC8B790>: 100%|██████████| 88/88 [00:04<00:00, 18.04 Samples/s]

# %%
# !mv lesion-diagnosis/solar-lentigo/output/* lesion-diagnosis/solar-lentigo/
# !mv lesion-diagnosis/vascular-lesion/output/* lesion-diagnosis/vascular-lesion/
# !mv lesion-diagnosis/dermatofibroma/output/* lesion-diagnosis/dermatofibroma/
# !mv lesion-diagnosis/squamous-cell-carcinoma/output/* lesion-diagnosis/squamous-cell-carcinoma/
# !mv lesion-diagnosis/actinic-keratosis/output/* lesion-diagnosis/actinic-keratosis/


# !rm -rf lesion-diagnosis/solar-lentigo/output
# !rm -rf lesion-diagnosis/vascular-lesion/output
# !rm -rf lesion-diagnosis/dermatofibroma/output
# !rm -rf lesion-diagnosis/squamous-cell-carcinoma/output
# !rm -rf lesion-diagnosis/actinic-keratosis/output

# %%
for dirpath, dirnames, filenames in os.walk("lesion-diagnosis"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 10 directories and 1 images in 'lesion-diagnosis'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/solar-lentigo'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/vascular-lesion'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/squamous-cell-carcinoma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/nevus'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/melanoma'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/actinic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/basal-cell-carcinoma'.
# There are 0 directories and 1000 images in 'lesion-diagnosis/dermatofibroma'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/seborrheic-keratosis'.
# There are 0 directories and 1002 images in 'lesion-diagnosis/pigmented-benign-keratosis'.

# %%
from ipythonUtils.generateTestTrain import generate_test_and_train_datasets
if not os.path.exists("train/actinic-keratosis"):
   generate_test_and_train_datasets()

# %%
import pathlib
import numpy as np

data_dir = pathlib.Path("train") 
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['actinic-keratosis' 'basal-cell-carcinoma' 'dermatofibroma' 'melanoma'
#  'nevus' 'pigmented-benign-keratosis' 'seborrheic-keratosis'
#  'solar-lentigo' 'squamous-cell-carcinoma' 'vascular-lesion']

# %%
data_dir_train = pathlib.Path("train")
data_dir_test = pathlib.Path("test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.JPG')))
image_count_test = len(list(data_dir_test.glob('*/*.JPG')))
image_count_train, image_count_test
# Out:
# (7989, 2001)

# %%
from ipythonUtils.generateTestTrain import view_random_image
img = view_random_image(target_dir="train", target_class="melanoma")
# Out:
# Image shape: (480, 640, 3)

# %%
img2 = view_random_image(target_dir="test", target_class="nevus")
# Out:
# Image shape: (2448, 3264, 3)

# %%
batch_size = 32
img_height = 224
img_width = 224
num_classes = len(class_names)
IMAGE_SHAPE = (img_width, img_height)
BATCH_SIZE = 32
epochs = 50

# %%
import tensorflow as tf

## create train dataset

## get all the train images and resizing them to the size of img_height*img_width and create batches
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 7989 files belonging to 10 classes.
# Using 6392 files for training.

# %%
## create validation dataset
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 7989 files belonging to 10 classes.
# Using 1597 files for validation.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(len(class_names)-1):
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.subplot(3, 3, i + 1)
    plt.imshow(img)
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %%
mobilenet_v2_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4"

# %%
# Create tensorboard callback (functionized because need to create a new one for each model)
import datetime
def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# %%
def create_model(model_url, num_classes=10):
  """Takes a TensorFlow Hub URL and creates a Keras Sequential model with it.
  
  Args:
    model_url (str): A TensorFlow Hub feature extraction URL.
    num_classes (int): Number of output neurons in output layer,
      should be equal to number of target classes, default 10.

  Returns:
    An uncompiled Keras Sequential model with model_url as feature
    extractor layer and Dense output layer with num_classes outputs.
  """
  # Download the pretrained model and save it as a Keras layer
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_SHAPE+(3,)) # define the input image shape
  
  # Create our own model
  model = tf.keras.Sequential([
    feature_extractor_layer, # use the feature extraction layer as the base
    layers.Dense(num_classes, activation='softmax', name='output_layer') # create our own output layer      
  ])

  return model

# %%
# Create model
mobilenet_v2_model = create_model(mobilenet_v2_url, num_classes=num_classes)

# Compile
mobilenet_v2_model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy'])

# %%
# Fit the model
mobilenet_v2_history = mobilenet_v2_model.fit(train_dataset,
                                  epochs=2,
                                  steps_per_epoch=len(train_dataset),
                                  validation_data=val_dataset,
                                  validation_steps=len(val_dataset),
                                  # Add TensorBoard callback to model (callbacks parameter takes a list)
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", # save experiment logs here
                                                                         experiment_name="mobilenet_v2")]) # name of log files
# Out:
# Saving TensorBoard log files to: tensorflow_hub/mobilenet_v2/20221016-195634
# Epoch 1/2
# 200/200 [==============================] - 88s 118ms/step - loss: 2.1017 - accuracy: 0.2696 - val_loss: 1.9044 - val_accuracy: 0.3312
# Epoch 2/2
# 200/200 [==============================] - 10s 48ms/step - loss: 1.8596 - accuracy: 0.3426 - val_loss: 1.9367 - val_accuracy: 0.3093

# %%
# If you wanted to, you could really turn this into a helper function to load in with a helper.py script...
import matplotlib.pyplot as plt

# Plot the validation and training data separately
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(mobilenet_v2_history)

# %%
# Resnet summary 
mobilenet_v2_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (K  (None, 1001)             3540265
#  erasLayer)
#
#  output_layer (Dense)        (None, 10)                10020
#
# =================================================================
# Total params: 3,550,285
# Trainable params: 10,020
# Non-trainable params: 3,540,265
# _________________________________________________________________

# %%
from tensorflow import keras

data_augmentation = keras.Sequential([
      layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
from glob import glob
path_list = [ x for x in glob(os.path.join(data_dir_train, '*', '*.JPG')) ] 
lesion_list = [ os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.JPG')) ]
print(len(lesion_list))
# Out:
# 7989

# %%
df_dict_original = dict(zip(path_list, lesion_list))
list(df_dict_original.items())[:2]
# Out:
# [('train/solar-lentigo/ISIC_0135990.JPG', 'solar-lentigo'),
#  ('train/solar-lentigo/solar-lentigo_original_ISIC_6548523.JPG_7c9bb859-c403-4e9d-a4e2-96ae72089673.JPG',
#   'solar-lentigo')]

# %%
import pandas as pd
original_df = pd.DataFrame(list(df_dict_original.items()), columns=['Path','Label'])
original_df.head()
# Out:
#                                                 Path          Label
# 0               train/solar-lentigo/ISIC_0135990.JPG  solar-lentigo
# 1  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 2               train/solar-lentigo/ISIC_7904757.JPG  solar-lentigo
# 3  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 4               train/solar-lentigo/ISIC_0011640.JPG  solar-lentigo

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# basal-cell-carcinoma          799
# dermatofibroma                799
# melanoma                      799
# nevus                         799
# pigmented-benign-keratosis    799
# seborrheic-keratosis          799
# solar-lentigo                 799
# squamous-cell-carcinoma       799
# vascular-lesion               799
# actinic-keratosis             798
# dtype: int64

# %%
original_df[['Label']].value_counts(normalize=True)
# Out:
# Label
# basal-cell-carcinoma          0.100013
# dermatofibroma                0.100013
# melanoma                      0.100013
# nevus                         0.100013
# pigmented-benign-keratosis    0.100013
# seborrheic-keratosis          0.100013
# solar-lentigo                 0.100013
# squamous-cell-carcinoma       0.100013
# vascular-lesion               0.100013
# actinic-keratosis             0.099887
# dtype: float64

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(1000) ## We are adding 1000 samples per class.
# Out:
# Initialised with 798 image(s) found.
# Output directory set to train/actinic-keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F0FB8B95A10>: 100%|██████████| 1000/1000 [02:00<00:00,  8.27 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/basal-cell-carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F0FC2D8C7D0>: 100%|██████████| 1000/1000 [01:49<00:00,  9.15 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F0ED2EA2410>: 100%|██████████| 1000/1000 [02:20<00:00,  7.12 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3264x2448 at 0x7F0FB8AC0250>: 100%|██████████| 1000/1000 [09:15<00:00,  1.80 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=5184x3456 at 0x7F0ED07AA910>: 100%|██████████| 1000/1000 [15:48<00:00,  1.05 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/pigmented-benign-keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F0EE64726D0>: 100%|██████████| 1000/1000 [00:28<00:00, 34.59 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/seborrheic-keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=4288x2848 at 0x7F0EE6625ED0>: 100%|██████████| 1000/1000 [04:06<00:00,  4.06 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/solar-lentigo/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F0ED2399A90>: 100%|██████████| 1000/1000 [07:01<00:00,  2.37 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/squamous-cell-carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F0F402EBA90>: 100%|██████████| 1000/1000 [02:09<00:00,  7.70 Samples/s]
# Initialised with 799 image(s) found.
# Output directory set to train/vascular-lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0EE66CD990>: 100%|██████████| 1000/1000 [01:18<00:00, 12.80 Samples/s]

# %%
total_train_images = len(list(data_dir_train.glob('*/output/*.JPG')))
print(total_train_images)
# Out:
# 10000

# %%
from glob import glob
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.JPG'))]
path_list_new[:2]
# Out:
# ['train/solar-lentigo/output/solar-lentigo_original_solar-lentigo_original_ISIC_0070238.JPG_6ce3da56-dc62-4157-99ac-b2c2d2d4c214.JPG_29f2a3fa-659d-44d7-966c-d42d0c22c1cd.JPG',
#  'train/solar-lentigo/output/solar-lentigo_original_ISIC_0651512.JPG_a2838ec4-bdef-4a95-9abe-e52ee1d73762.JPG']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.JPG'))]
lesion_list_new[:2]
# Out:
# ['solar-lentigo', 'solar-lentigo']

# %%
import pandas as pd
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

df_2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df_2)
new_df.shape
# Out:
# (17989, 2)

# %%
new_df.head()
# Out:
#                                                 Path          Label
# 0               train/solar-lentigo/ISIC_0135990.JPG  solar-lentigo
# 1  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 2               train/solar-lentigo/ISIC_7904757.JPG  solar-lentigo
# 3  train/solar-lentigo/solar-lentigo_original_ISI...  solar-lentigo
# 4               train/solar-lentigo/ISIC_0011640.JPG  solar-lentigo

# %%
# Checking the class distribution after adding the new images
new_df['Label'].value_counts(normalize=True)
# Out:
# solar-lentigo                 0.100006
# vascular-lesion               0.100006
# squamous-cell-carcinoma       0.100006
# nevus                         0.100006
# melanoma                      0.100006
# basal-cell-carcinoma          0.100006
# dermatofibroma                0.100006
# seborrheic-keratosis          0.100006
# pigmented-benign-keratosis    0.100006
# actinic-keratosis             0.099950
# Name: Label, dtype: float64

# %%
new_df['Label'].value_counts()
# Out:
# solar-lentigo                 1799
# vascular-lesion               1799
# squamous-cell-carcinoma       1799
# nevus                         1799
# melanoma                      1799
# basal-cell-carcinoma          1799
# dermatofibroma                1799
# seborrheic-keratosis          1799
# pigmented-benign-keratosis    1799
# actinic-keratosis             1798
# Name: Label, dtype: int64

# %%
# data_dir_train="path to directory with training data + data created using augmentor"
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 17989 files belonging to 10 classes.
# Using 14392 files for training.

# %%
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 17989 files belonging to 10 classes.
# Using 3597 files for validation.

# %%
# Fit the model
mobilenet_v2_history = mobilenet_v2_model.fit(train_dataset,
                                  epochs=epochs,
                                  steps_per_epoch=len(train_dataset),
                                  validation_data=val_dataset,
                                  validation_steps=len(val_dataset),
                                  # Add TensorBoard callback to model (callbacks parameter takes a list)
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", # save experiment logs here
                                                                         experiment_name="mobilenet_v2")]) # name of log files
# Out:
# Saving TensorBoard log files to: tensorflow_hub/mobilenet_v2/20221016-204444
# Epoch 1/50
# 450/450 [==============================] - 173s 378ms/step - loss: 1.7968 - accuracy: 0.3637 - val_loss: 1.7681 - val_accuracy: 0.3689
# Epoch 2/50
# 450/450 [==============================] - 157s 343ms/step - loss: 1.7153 - accuracy: 0.3942 - val_loss: 1.7242 - val_accuracy: 0.3850
# Epoch 3/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.6619 - accuracy: 0.4074 - val_loss: 1.7559 - val_accuracy: 0.3717
# Epoch 4/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.6321 - accuracy: 0.4192 - val_loss: 1.7610 - val_accuracy: 0.3653
# Epoch 5/50
# 450/450 [==============================] - 157s 344ms/step - loss: 1.6122 - accuracy: 0.4268 - val_loss: 1.7392 - val_accuracy: 0.3742
# Epoch 6/50
# 450/450 [==============================] - 157s 342ms/step - loss: 1.6014 - accuracy: 0.4339 - val_loss: 1.7273 - val_accuracy: 0.3825
# Epoch 7/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.5617 - accuracy: 0.4417 - val_loss: 1.7104 - val_accuracy: 0.3937
# Epoch 8/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.5634 - accuracy: 0.4472 - val_loss: 1.6689 - val_accuracy: 0.4087
# Epoch 9/50
# 450/450 [==============================] - 158s 345ms/step - loss: 1.5392 - accuracy: 0.4525 - val_loss: 1.6527 - val_accuracy: 0.4223
# Epoch 10/50
# 450/450 [==============================] - 157s 344ms/step - loss: 1.5323 - accuracy: 0.4532 - val_loss: 1.6309 - val_accuracy: 0.4156
# Epoch 11/50
# 450/450 [==============================] - 157s 342ms/step - loss: 1.5271 - accuracy: 0.4571 - val_loss: 1.6720 - val_accuracy: 0.4153
# Epoch 12/50
# 450/450 [==============================] - 157s 343ms/step - loss: 1.5061 - accuracy: 0.4653 - val_loss: 1.6987 - val_accuracy: 0.4070
# Epoch 13/50
# 450/450 [==============================] - 166s 363ms/step - loss: 1.5006 - accuracy: 0.4617 - val_loss: 1.6677 - val_accuracy: 0.4076
# Epoch 14/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.4872 - accuracy: 0.4705 - val_loss: 1.6161 - val_accuracy: 0.4384
# Epoch 15/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.4857 - accuracy: 0.4678 - val_loss: 1.5671 - val_accuracy: 0.4437
# Epoch 16/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.4767 - accuracy: 0.4737 - val_loss: 1.6319 - val_accuracy: 0.4273
# Epoch 17/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.4621 - accuracy: 0.4794 - val_loss: 1.6371 - val_accuracy: 0.4362
# Epoch 18/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.4639 - accuracy: 0.4765 - val_loss: 1.5872 - val_accuracy: 0.4409
# Epoch 19/50
# 450/450 [==============================] - 158s 345ms/step - loss: 1.4494 - accuracy: 0.4828 - val_loss: 1.5970 - val_accuracy: 0.4415
# Epoch 20/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.4535 - accuracy: 0.4821 - val_loss: 1.5895 - val_accuracy: 0.4468
# Epoch 21/50
# 450/450 [==============================] - 157s 343ms/step - loss: 1.4430 - accuracy: 0.4880 - val_loss: 1.6766 - val_accuracy: 0.4123
# Epoch 22/50
# 450/450 [==============================] - 157s 343ms/step - loss: 1.4400 - accuracy: 0.4935 - val_loss: 1.6115 - val_accuracy: 0.4370
# Epoch 23/50
# 450/450 [==============================] - 157s 344ms/step - loss: 1.4293 - accuracy: 0.4911 - val_loss: 1.6071 - val_accuracy: 0.4267
# Epoch 24/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.4487 - accuracy: 0.4839 - val_loss: 1.5784 - val_accuracy: 0.4534
# Epoch 25/50
# 450/450 [==============================] - 157s 343ms/step - loss: 1.4278 - accuracy: 0.4936 - val_loss: 1.6164 - val_accuracy: 0.4526
# Epoch 26/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.4158 - accuracy: 0.4949 - val_loss: 1.6459 - val_accuracy: 0.4323
# Epoch 27/50
# 450/450 [==============================] - 157s 342ms/step - loss: 1.4149 - accuracy: 0.5039 - val_loss: 1.6026 - val_accuracy: 0.4390
# Epoch 28/50
# 450/450 [==============================] - 156s 340ms/step - loss: 1.4162 - accuracy: 0.4983 - val_loss: 1.5924 - val_accuracy: 0.4412
# Epoch 29/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.4159 - accuracy: 0.4971 - val_loss: 1.5729 - val_accuracy: 0.4520
# Epoch 30/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.4038 - accuracy: 0.5028 - val_loss: 1.5756 - val_accuracy: 0.4529
# Epoch 31/50
# 450/450 [==============================] - 156s 340ms/step - loss: 1.3962 - accuracy: 0.5068 - val_loss: 1.7601 - val_accuracy: 0.4304
# Epoch 32/50
# 450/450 [==============================] - 155s 339ms/step - loss: 1.3985 - accuracy: 0.5067 - val_loss: 1.5438 - val_accuracy: 0.4629
# Epoch 33/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.3969 - accuracy: 0.5020 - val_loss: 1.5809 - val_accuracy: 0.4523
# Epoch 34/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.3970 - accuracy: 0.5054 - val_loss: 1.7267 - val_accuracy: 0.3995
# Epoch 35/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.3853 - accuracy: 0.5073 - val_loss: 1.5607 - val_accuracy: 0.4590
# Epoch 36/50
# 450/450 [==============================] - 157s 343ms/step - loss: 1.3759 - accuracy: 0.5106 - val_loss: 1.5734 - val_accuracy: 0.4540
# Epoch 37/50
# 450/450 [==============================] - 155s 340ms/step - loss: 1.3743 - accuracy: 0.5110 - val_loss: 1.6422 - val_accuracy: 0.4534
# Epoch 38/50
# 450/450 [==============================] - 155s 340ms/step - loss: 1.3717 - accuracy: 0.5135 - val_loss: 1.6022 - val_accuracy: 0.4598
# Epoch 39/50
# 450/450 [==============================] - 157s 342ms/step - loss: 1.3628 - accuracy: 0.5150 - val_loss: 1.6383 - val_accuracy: 0.4473
# Epoch 40/50
# 450/450 [==============================] - 155s 340ms/step - loss: 1.3754 - accuracy: 0.5168 - val_loss: 1.5775 - val_accuracy: 0.4554
# Epoch 41/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.3910 - accuracy: 0.5052 - val_loss: 1.5980 - val_accuracy: 0.4443
# Epoch 42/50
# 450/450 [==============================] - 165s 362ms/step - loss: 1.3639 - accuracy: 0.5139 - val_loss: 1.5401 - val_accuracy: 0.4732
# Epoch 43/50
# 450/450 [==============================] - 155s 339ms/step - loss: 1.3602 - accuracy: 0.5164 - val_loss: 1.5580 - val_accuracy: 0.4607
# Epoch 44/50
# 450/450 [==============================] - 156s 340ms/step - loss: 1.3555 - accuracy: 0.5223 - val_loss: 1.5565 - val_accuracy: 0.4654
# Epoch 45/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.3616 - accuracy: 0.5181 - val_loss: 1.5247 - val_accuracy: 0.4696
# Epoch 46/50
# 450/450 [==============================] - 155s 339ms/step - loss: 1.3675 - accuracy: 0.5146 - val_loss: 1.6491 - val_accuracy: 0.4317
# Epoch 47/50
# 450/450 [==============================] - 156s 341ms/step - loss: 1.3458 - accuracy: 0.5259 - val_loss: 1.5714 - val_accuracy: 0.4598
# Epoch 48/50
# 450/450 [==============================] - 156s 340ms/step - loss: 1.3465 - accuracy: 0.5190 - val_loss: 1.5347 - val_accuracy: 0.4701
# Epoch 49/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.3568 - accuracy: 0.5201 - val_loss: 1.6070 - val_accuracy: 0.4423
# Epoch 50/50
# 450/450 [==============================] - 156s 342ms/step - loss: 1.3524 - accuracy: 0.5181 - val_loss: 1.5681 - val_accuracy: 0.4623

# %%
plot_loss_curves(mobilenet_v2_history)

# %%
acc = mobilenet_v2_history.history['accuracy']
val_accuracy = mobilenet_v2_history.history['val_accuracy']

loss = mobilenet_v2_history.history['loss']
val_loss = mobilenet_v2_history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# mobilenet_v2 summary 
mobilenet_v2_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (K  (None, 1001)             3540265
#  erasLayer)
#
#  output_layer (Dense)        (None, 10)                10020
#
# =================================================================
# Total params: 3,550,285
# Trainable params: 10,020
# Non-trainable params: 3,540,265
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

plot_model(mobilenet_v2_model, show_shapes=True, show_layer_names=True)

# %%
def plot_history(history):
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('Train loss vs Validation loss')
  plt.ylabel('loss') 
  plt.xlabel('epoch') 
  plt.legend([ 'train' , 'validation' ], loc='upper right') 
  plt.show()


plot_history(mobilenet_v2_history)

# %%
plt.plot(mobilenet_v2_history.history['accuracy'])
plt.plot(mobilenet_v2_history.history['val_accuracy'])
plt.title('Train accuracy vs Validation Accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch') 
plt.legend([ 'train' , 'validation' ], loc= 'upper right') 
plt.show()
